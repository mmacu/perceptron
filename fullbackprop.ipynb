# %%
import pandas

from data_reader import csv_data_read, class_train_files, class_test_files, pres_class_train, pres_class_test, \
    read_test_mnist
from nn_visualisation import *

from nn_model import *
from data_reader import read_train_mnist





#,act_f=Sigm,act_fprim=Sigmprim)

path='projekt1/classification/'
path1='projekt1-oddanie/clasification/'

#train_f_name=path+class_train_files[5]
#test_f_name=path+class_test_files[5]
#pliki na oddaniu:
train_f_name=path1+pres_class_train[5]
test_f_name=path1+pres_class_test[5]
np.random.seed(323)
train_data=csv_data_read(train_f_name)
test_data=csv_data_read(test_f_name)


X,y=read_train_mnist()
Xt,yt=read_test_mnist()
y=y
yt=yt

XY=np.zeros((len(X),len(X[0])+1),dtype=np.float64)
XYt=np.zeros((len(Xt),len(Xt[0])+1),dtype=np.float64)
for i in range(len(X)):
    XY[i][0:len(X[i])]=X[i]

    XY[i][-1]=y[i]

for i in range(len(Xt)):
    XYt[i][0:len(Xt[i])] = Xt[i]

    XYt[i][-1] = yt[i]

# %%
m1=nn_model([len(X[0]),800,400,200,10],with_bias=True,act_f=Sigm2,act_fprim=Sigmprim2,
            learn_ratio=0.0005,with_noise=False,classifier=True,change_m_ratio=0.99)

# %%
epochs=1

vis=SimpleVis(m1)

# %%
learning_error=m1.fit(XY,epochs=epochs,vis=vis)
# Out:
# Bład w trakcie epoki: 2.0
# Bład w trakcie epoki: 0.6233766233766234
# Bład w trakcie epoki: 0.5182408795602199
# Bład w trakcie epoki: 0.437187604131956
# Bład w trakcie epoki: 0.39915021244688825
# Bład w trakcie epoki: 0.372125574885023
# Bład w trakcie epoki: 0.3506082319613398
# Bład w trakcie epoki: 0.33223825167833165
# Bład w trakcie epoki: 0.3145856767904012
# Bład w trakcie epoki: 0.30418842350849906
# Bład w trakcie epoki: 0.2920707929207079
# Bład w trakcie epoki: 0.28224706844832287
# Bład w trakcie epoki: 0.2743938005166236
# Bład w trakcie epoki: 0.26951772940543034
# Bład w trakcie epoki: 0.26055281765588173
# Bład w trakcie epoki: 0.25584961002599826
# Bład w trakcie epoki: 0.24910943066058372
# Bład w trakcie epoki: 0.24145638491853422
# Bład w trakcie epoki: 0.23548691739347813
# Bład w trakcie epoki: 0.23188253249828955
# Bład w trakcie epoki: 0.22658867056647167
# Bład w trakcie epoki: 0.22270368077710584
# Bład w trakcie epoki: 0.21849006863324394
# Bład w trakcie epoki: 0.21481674709795226
# Bład w trakcie epoki: 0.21044956460147493
# Bład w trakcie epoki: 0.20663173473061078
# Bład w trakcie epoki: 0.20276143225260568
# Bład w trakcie epoki: 0.19869634457983038
# Bład w trakcie epoki: 0.19567158315774436
# Bład w trakcie epoki: 0.19251060308265233
# Bład w trakcie epoki: 0.18926035798806706
# Bład w trakcie epoki: 0.18660688364891456
# Bład w trakcie epoki: 0.18436923846129807
# Bład w trakcie epoki: 0.18214599557589164
# Bład w trakcie epoki: 0.1795829534425458
# Bład w trakcie epoki: 0.1775092140224565
# Bład w trakcie epoki: 0.17557845615399573
# Bład w trakcie epoki: 0.1739142185346342
# Bład w trakcie epoki: 0.17215336438514775
# Bład w trakcie epoki: 0.16991872003281966
# Bład w trakcie epoki: 0.16837079073023176
# Bład w trakcie epoki: 0.1669959269286115
# Bład w trakcie epoki: 0.16544844170376896
# Bład w trakcie epoki: 0.164484546871003
# Bład w trakcie epoki: 0.16247358014590577
# Bład w trakcie epoki: 0.16099642230172662
# Bład w trakcie epoki: 0.1595400099997826
# Bład w trakcie epoki: 0.1578051530818493
# Bład w trakcie epoki: 0.15651757255057186
# Bład w trakcie epoki: 0.15524172976061712
# Bład w trakcie epoki: 0.15387692246155077
# Bład w trakcie epoki: 0.15295778514146782
# Bład w trakcie epoki: 0.15193938578104269
# Bład w trakcie epoki: 0.15063866719495858
# Bład w trakcie epoki: 0.14957130423510676
# Bład w trakcie epoki: 0.1486336612061599
# Bład w trakcie epoki: 0.14756879341440332
# Bład w trakcie epoki: 0.14643602743811512
# Bład w trakcie epoki: 0.14529059843795797
# Bład w trakcie epoki: 0.14411620142031492
# Błąd: 0.1434

# %%
epochs=1

# %%
learning_error=m1.fit(XY,epochs=epochs,vis=vis)
# Out:
# Bład w trakcie epoki: 0.0
# Bład w trakcie epoki: 0.07492507492507493
# Bład w trakcie epoki: 0.07396301849075462
# Bład w trakcie epoki: 0.07764078640453183
# Bład w trakcie epoki: 0.07848037990502374
# Bład w trakcie epoki: 0.07718456308738253
# Bład w trakcie epoki: 0.07465422429595067
# Bład w trakcie epoki: 0.07213255249250107
# Bład w trakcie epoki: 0.0699912510936133
# Bład w trakcie epoki: 0.07021442061993112
# Bład w trakcie epoki: 0.06999300069993
# Bład w trakcie epoki: 0.0684483228797382
# Bład w trakcie epoki: 0.06791100741604866
# Bład w trakcie epoki: 0.0680716867933236
# Bład w trakcie epoki: 0.06763802585529605
# Bład w trakcie epoki: 0.06772881807879474
# Bład w trakcie epoki: 0.06787075807762015
# Bład w trakcie epoki: 0.06917240162343391
# Bład w trakcie epoki: 0.06955169157269041
# Bład w trakcie epoki: 0.06847008052207779
# Bład w trakcie epoki: 0.06754662266886656
# Bład w trakcie epoki: 0.06790152849864292
# Bład w trakcie epoki: 0.06849688650515885
# Bład w trakcie epoki: 0.06804051997739229
# Bład w trakcie epoki: 0.06766384733969417
# Bład w trakcie epoki: 0.06847726090956362
# Bład w trakcie epoki: 0.06834352524902888
# Bład w trakcie epoki: 0.06825673123217658
# Bład w trakcie epoki: 0.06881897075104461
# Bład w trakcie epoki: 0.069342436467708
# Bład w trakcie epoki: 0.06946435118829372
# Bład w trakcie epoki: 0.06906228831328022
# Bład w trakcie epoki: 0.06965407331020905
# Bład w trakcie epoki: 0.06963425350746948
# Bład w trakcie epoki: 0.0689685597482427
# Bład w trakcie epoki: 0.06842661638238907
# Bład w trakcie epoki: 0.06822032721313297
# Bład w trakcie epoki: 0.06772789924596632
# Bład w trakcie epoki: 0.06781400489460804
# Bład w trakcie epoki: 0.06730596651367914
# Bład w trakcie epoki: 0.06737331566710832
# Bład w trakcie epoki: 0.0673398209799761
# Bład w trakcie epoki: 0.06737934811075927
# Bład w trakcie epoki: 0.06732401572056464
# Bład w trakcie epoki: 0.06697575055112384
# Bład w trakcie epoki: 0.06666518521810627
# Bład w trakcie epoki: 0.06656377035281842
# Bład w trakcie epoki: 0.06625390949128741
# Bład w trakcie epoki: 0.06597779212933064
# Bład w trakcie epoki: 0.06591702210158977
# Bład w trakcie epoki: 0.06601867962640748
# Bład w trakcie epoki: 0.06576341640359994
# Bład w trakcie epoki: 0.06578719640006923
# Bład w trakcie epoki: 0.06567800607535706
# Bład w trakcie epoki: 0.06555434158626693
# Bład w trakcie epoki: 0.0655624443191942
# Bład w trakcie epoki: 0.06560597132194068
# Bład w trakcie epoki: 0.06570060174382905
# Bład w trakcie epoki: 0.06568852261167911
# Bład w trakcie epoki: 0.06571075066524296
# Błąd: 0.06605

# %%
learning_error=m1.fit(XY,epochs=epochs,vis=vis)
# Out:
# Bład w trakcie epoki: 0.0
# Bład w trakcie epoki: 0.02097902097902098
# Bład w trakcie epoki: 0.01999000499750125
# Bład w trakcie epoki: 0.022325891369543487
# Bład w trakcie epoki: 0.023994001499625092
# Bład w trakcie epoki: 0.024795040991801638
# Bład w trakcie epoki: 0.02382936177303783
# Bład w trakcie epoki: 0.023996571918297387
# Bład w trakcie epoki: 0.025121859767529058
# Bład w trakcie epoki: 0.024997222530829907
# Bład w trakcie epoki: 0.025997400259974
# Bład w trakcie epoki: 0.025634033269702754
# Bład w trakcie epoki: 0.0251645696191984
# Bład w trakcie epoki: 0.02453657410968387
# Bład w trakcie epoki: 0.024641097064495392
# Bład w trakcie epoki: 0.025064995666955536
# Bład w trakcie epoki: 0.025060933691644274
# Bład w trakcie epoki: 0.0253514499147109
# Bład w trakcie epoki: 0.025443030942725403
# Bład w trakcie epoki: 0.02578811641492553
# Bład w trakcie epoki: 0.02624868756562172
# Bład w trakcie epoki: 0.026379696204942623
# Bład w trakcie epoki: 0.026226080632698514
# Bład w trakcie epoki: 0.026651015173253335
# Bład w trakcie epoki: 0.02645723094871047
# Bład w trakcie epoki: 0.026158953641854325
# Bład w trakcie epoki: 0.02630668051228799
# Bład w trakcie epoki: 0.026591607718232657
# Bład w trakcie epoki: 0.026749044676975822
# Bład w trakcie epoki: 0.02686114271921658
# Bład w trakcie epoki: 0.027032432252258258
# Bład w trakcie epoki: 0.02683784394051805
# Bład w trakcie epoki: 0.027155401393706445
# Bład w trakcie epoki: 0.02727190085148935
# Bład w trakcie epoki: 0.027440369400899972
# Bład w trakcie epoki: 0.027513499614296735
# Bład w trakcie epoki: 0.027610344157106746
# Bład w trakcie epoki: 0.027756006594416367
# Bład w trakcie epoki: 0.027867687692429147
# Bład w trakcie epoki: 0.027845439860516397
# Bład w trakcie epoki: 0.027799305017374567
# Bład w trakcie epoki: 0.027804199897563473
# Bład w trakcie epoki: 0.02785647960762839
# Bład w trakcie epoki: 0.027999348852352272
# Bład w trakcie epoki: 0.027953910138405945
# Bład w trakcie epoki: 0.028132708162040842
# Bład w trakcie epoki: 0.028195039238277427
# Bład w trakcie epoki: 0.027850471266568796
# Bład w trakcie epoki: 0.027791087685673215
# Bład w trakcie epoki: 0.027836166608844717
# Bład w trakcie epoki: 0.027779444411111777
# Bład w trakcie epoki: 0.02782298386306151
# Bład w trakcie epoki: 0.02771100555758543
# Bład w trakcie epoki: 0.027622120337352125
# Bład w trakcie epoki: 0.02762911797929668
# Bład w trakcie epoki: 0.02765404265376993
# Bład w trakcie epoki: 0.027624506705237407
# Bład w trakcie epoki: 0.02752583288012491
# Bład w trakcie epoki: 0.027551249116394543
# Bład w trakcie epoki: 0.027558854934662123
# Błąd: 0.0277

# %%
learning_error=m1.fit(XY,epochs=epochs,vis=vis)
# Out:
# Bład w trakcie epoki: 0.0
# Bład w trakcie epoki: 0.007992007992007992
# Bład w trakcie epoki: 0.009995002498750625
# Bład w trakcie epoki: 0.009330223258913695
# Bład w trakcie epoki: 0.010247438140464884
# Bład w trakcie epoki: 0.010797840431913617
# Bład w trakcie epoki: 0.0113314447592068
# Bład w trakcie epoki: 0.011569775746321955
# Bład w trakcie epoki: 0.011373578302712161
# Bład w trakcie epoki: 0.012554160648816799
# Bład w trakcie epoki: 0.012198780121987801
# Bład w trakcie epoki: 0.012271611671666212
# Bład w trakcie epoki: 0.012498958420131656
# Bład w trakcie epoki: 0.012691331436043382
# Bład w trakcie epoki: 0.012570530676380259
# Bład w trakcie epoki: 0.012999133391107259
# Bład w trakcie epoki: 0.013061683644772202
# Bład w trakcie epoki: 0.013234515616728428
# Bład w trakcie epoki: 0.01327704016443531
# Bład w trakcie epoki: 0.013420346297563286
# Bład w trakcie epoki: 0.0135993200339983
# Bład w trakcie epoki: 0.013618399123851245
# Bład w trakcie epoki: 0.0141357211035862
# Bład w trakcie epoki: 0.01408634407199687
# Bład w trakcie epoki: 0.014291071205366443
# Bład w trakcie epoki: 0.014279428822847086
# Bład w trakcie epoki: 0.014730202684512134
# Bład w trakcie epoki: 0.01470315914225399
# Bład w trakcie epoki: 0.014713760222849185
# Bład w trakcie epoki: 0.014930519637253888
# Bład w trakcie epoki: 0.014999500016666112
# Bład w trakcie epoki: 0.015257572336376245
# Bład w trakcie epoki: 0.015343270522796163
# Bład w trakcie epoki: 0.015272264476834035
# Bład w trakcie epoki: 0.015323078732978442
# Bład w trakcie epoki: 0.015370989400302848
# Bład w trakcie epoki: 0.015221799394461265
# Bład w trakcie epoki: 0.015296883868003567
# Bład w trakcie epoki: 0.01531538643719902
# Bład w trakcie epoki: 0.015256019076433938
# Bład w trakcie epoki: 0.015274618134546636
# Bład w trakcie epoki: 0.015316699592692861
# Bład w trakcie epoki: 0.015499630961167592
# Bład w trakcie epoki: 0.01569730936489849
# Bład w trakcie epoki: 0.01568146178495943
# Bład w trakcie epoki: 0.015732983711473077
# Bład w trakcie epoki: 0.015782265602921675
# Bład w trakcie epoki: 0.015701793578860024
# Bład w trakcie epoki: 0.015624674485948209
# Bład w trakcie epoki: 0.015632334033999305
# Bład w trakcie epoki: 0.015799684006319873
# Bład w trakcie epoki: 0.01592125644595204
# Bład w trakcie epoki: 0.01601892271302475
# Bład w trakcie epoki: 0.016131771098658515
# Bład w trakcie epoki: 0.016147849113905297
# Bład w trakcie epoki: 0.01619970545990073
# Bład w trakcie epoki: 0.016303280298566095
# Bład w trakcie epoki: 0.016403220996122875
# Bład w trakcie epoki: 0.016568679850347406
# Bład w trakcie epoki: 0.016711581159641362
# Błąd: 0.016766666666666666

# %%
sc=m1.score(XYt)

# %%
sc
# Out:
# 0.0275

# %%
px=X[13430]

# %%
len(px)
# Out:
# 784

# %%
k=0
for i in range(1000):
    r=m1.evaluate(Xt[i])
    if r[0]!=yt[i]:
        k+=1
        px=np.array(Xt[i])
        px.shape=(28,28)
        plt.imshow(px, cmap='gray', vmin=0, vmax=255)
        plt.title(str(k)+" Result:"+ str(r[0])+" Expected: "+str(yt[i]))
        plt.show()

# %%
import pickle
filem1=open("m1fullbackprop.dmp","wb")

# %%
pickle.dump(m1,filem1)
